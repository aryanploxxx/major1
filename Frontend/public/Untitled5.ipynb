# %%
pip install astropy
# Out:
# Requirement already satisfied: astropy in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (6.1.3)
# Requirement already satisfied: numpy>=1.23 in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (1.26.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.29.0.32.7 in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (0.2024.9.16.0.32.21)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\aryan gupta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (23.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import astropy
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.io import fits

# %%
hdu_list = fits.open('./AIA20100513_0000_0094.fits')
hdu_list.info()
# Out:
# Filename: ./AIA20100513_0000_0094.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  COMPRESSED_IMAGE    1 CompImageHDU    170   (1024, 1024)   int32

# %%
image_data = hdu_list[0].data

# %%
from astropy.utils.data import download_file
image_file = 'AIA20100513_0000_0094.fits'

# %%
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: AIA20100513_0000_0094.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  COMPRESSED_IMAGE    1 CompImageHDU    170   (1024, 1024)   int32

# %%
image_data = hdu_list[1].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (1024, 1024)

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()

# %%
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))
# Out:
# Min: -10.0625
# Max: 148.3125
# Mean: 1.2179321646690369
# Stdev: 1.8033876924123209

# %%
print(type(image_data.flatten()))
print(image_data.flatten().shape)
# Out:
# <class 'numpy.ndarray'>
# (1048576,)

# %%
histogram = plt.hist(image_data.flatten(), bins='auto')
